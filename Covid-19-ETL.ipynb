# %% [markdown]
# # COVID-19 ETL
#
# This notebook is used to load, clean COVID-19 data and export it to PostgreSQL. The data contains:
#
# * Data on COVID-19 (coronavirus) by Our World in Data: https://github.com/owid/covid-19-data/tree/master/public/data
# * Data on COVID-19 (coronavirus) vaccinations by Our World in Data: https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations
# * COVID-19 Case Surveillance Public Use Data with Geography: https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Global COVID-19 Data

# %%
covid_data = "./resources/owid-covid-data.csv"

covid_data_df = pd.read_csv(covid_data)
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 80981      ZWE    Africa     Zimbabwe  2021-04-07      36984.0       18.0
# 80982      ZWE    Africa     Zimbabwe  2021-04-08      37052.0       68.0
# 80983      ZWE    Africa     Zimbabwe  2021-04-09      37147.0       95.0
# 80984      ZWE    Africa     Zimbabwe  2021-04-10      37273.0      126.0
# 80985      ZWE    Africa     Zimbabwe  2021-04-11      37288.0       15.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 80981              14.571        1531.0         0.0                1.143  ...
# 80982              22.286        1532.0         1.0                1.286  ...
# 80983              34.857        1535.0         3.0                1.571  ...
# 80984              51.714        1538.0         3.0                2.000  ...
# 80985              52.143        1538.0         0.0                1.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 80981        1899.775             21.4                307.846
# 80982        1899.775             21.4                307.846
# 80983        1899.775             21.4                307.846
# 80984        1899.775             21.4                307.846
# 80985        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 80981                 1.82             1.6          30.7
# 80982                 1.82             1.6          30.7
# 80983                 1.82             1.6          30.7
# 80984                 1.82             1.6          30.7
# 80985                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 80981                  36.791                         1.7            61.49
# 80982                  36.791                         1.7            61.49
# 80983                  36.791                         1.7            61.49
# 80984                  36.791                         1.7            61.49
# 80985                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 80981                    0.571
# 80982                    0.571
# 80983                    0.571
# 80984                    0.571
# 80985                    0.571
#
# [80986 rows x 59 columns]

# %%
# Unefficient way of finding the last row of each country and inserting it into a new dataframe
# Ideally, making a list and appending it to a new dataframe would be much more efficient
# But there are so many columns that time-wise this takes less time

countries = covid_data_df["location"].unique().tolist()
stats = pd.DataFrame()

for country in countries:
    df = covid_data_df.loc[covid_data_df["location"] == country]
    df = df.iloc[-1].to_frame().T
    stats = pd.concat([stats,df])

# %%
# Dataframe to be used for scatter plots - needs some cleaning (probably) 
# la forma de buscar pordria ser usando max en vez del ultimo de la fila, dependiendo de la columna en la que se haga 
stats
# Out:
#        iso_code continent     location        date  total_cases new_cases  \
# 412         AFG      Asia  Afghanistan  2021-04-11        57160        16
# 836    OWID_AFR       NaN       Africa  2021-04-11   4.3502e+06      9684
# 1248        ALB    Europe      Albania  2021-04-11       128393       238
# 1660        DZA    Africa      Algeria  2021-04-11       118516       138
# 2066        AND    Europe      Andorra  2021-04-11        12545        48
# ...         ...       ...          ...         ...          ...       ...
# 79394       VNM      Asia      Vietnam  2021-04-11         2693         1
# 79840  OWID_WRL       NaN        World  2021-04-11  1.36047e+08    690739
# 80207       YEM      Asia        Yemen  2021-04-11         5357        81
# 80597       ZMB    Africa       Zambia  2021-04-11        90029       111
# 80985       ZWE    Africa     Zimbabwe  2021-04-11        37288        15
#
#       new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 412               69.143         2521          0               3.429  ...
# 836              11325.6       115710        288             265.286  ...
# 1248                 266         2317          7               7.429  ...
# 1660             127.714         3130          4               3.571  ...
# 2066              44.857          120          0               0.429  ...
# ...                  ...          ...        ...                 ...  ...
# 79394              8.857           35          0                   0  ...
# 79840             674669  2.93636e+06       8557               11871  ...
# 80207             79.857         1049         18              14.714  ...
# 80597                157         1226          0               0.857  ...
# 80985             52.143         1538          0               1.857  ...
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate  \
# 412          1803.99             NaN               597.029
# 836              NaN             NaN                   NaN
# 1248         11803.4             1.1               304.195
# 1660         13913.8             0.5               278.364
# 2066             NaN             NaN               109.135
# ...              ...             ...                   ...
# 79394        6171.88               2               245.465
# 79840        15469.2              10                233.07
# 80207        1479.15            18.8               495.003
# 80597        3689.25            57.5               234.499
# 80985        1899.78            21.4               307.846
#
#       diabetes_prevalence female_smokers male_smokers handwashing_facilities  \
# 412                  9.59            NaN          NaN                 37.746
# 836                   NaN            NaN          NaN                    NaN
# 1248                10.08            7.1         51.2                    NaN
# 1660                 6.73            0.7         30.4                 83.741
# 2066                 7.97             29         37.8                    NaN
# ...                   ...            ...          ...                    ...
# 79394                   6              1         45.9                 85.847
# 79840                8.51          6.434       34.635                  60.13
# 80207                5.35            7.6         29.2                 49.542
# 80597                3.94            3.1         24.7                 13.938
# 80985                1.82            1.6         30.7                 36.791
#
#       hospital_beds_per_thousand life_expectancy human_development_index
# 412                          0.5           64.83                   0.511
# 836                          NaN             NaN                     NaN
# 1248                        2.89           78.57                   0.795
# 1660                         1.9           76.88                   0.748
# 2066                         NaN           83.73                   0.868
# ...                          ...             ...                     ...
# 79394                        2.6            75.4                   0.704
# 79840                      2.705           72.58                   0.737
# 80207                        0.7           66.12                    0.47
# 80597                          2           63.89                   0.584
# 80985                        1.7           61.49                   0.571
#
# [215 rows x 59 columns]

# %% [markdown]
# ## US COVID-19 Data

# %%
# Get data from US only
covid_data_df_us = covid_data_df.loc[covid_data_df["location"] == "United States"]
covid_data_df_us
# Out:
#       iso_code      continent       location        date  total_cases  \
# 76767      USA  North America  United States  2020-01-22          1.0
# 76768      USA  North America  United States  2020-01-23          1.0
# 76769      USA  North America  United States  2020-01-24          2.0
# 76770      USA  North America  United States  2020-01-25          2.0
# 76771      USA  North America  United States  2020-01-26          5.0
# ...        ...            ...            ...         ...          ...
# 77208      USA  North America  United States  2021-04-07   30922386.0
# 77209      USA  North America  United States  2021-04-08   31002264.0
# 77210      USA  North America  United States  2021-04-09   31084962.0
# 77211      USA  North America  United States  2021-04-10   31151495.0
# 77212      USA  North America  United States  2021-04-11   31197873.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 76767        NaN                 NaN           NaN         NaN
# 76768        0.0                 NaN           NaN         NaN
# 76769        1.0                 NaN           NaN         NaN
# 76770        0.0                 NaN           NaN         NaN
# 76771        3.0                 NaN           NaN         NaN
# ...          ...                 ...           ...         ...
# 77208    75038.0           65936.000      559202.0      2570.0
# 77209    79878.0           66056.571      560202.0      1000.0
# 77210    82698.0           67896.000      561074.0       872.0
# 77211    66533.0           68404.429      561783.0       709.0
# 77212    46378.0           70039.571      562066.0       283.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 76767                  NaN  ...       54225.446              1.2
# 76768                  NaN  ...       54225.446              1.2
# 76769                  NaN  ...       54225.446              1.2
# 76770                  NaN  ...       54225.446              1.2
# 76771                  NaN  ...       54225.446              1.2
# ...                    ...  ...             ...              ...
# 77208              989.286  ...       54225.446              1.2
# 77209              979.571  ...       54225.446              1.2
# 77210              970.000  ...       54225.446              1.2
# 77211              969.429  ...       54225.446              1.2
# 77212              969.286  ...       54225.446              1.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 76767                151.089                10.79            19.1
# 76768                151.089                10.79            19.1
# 76769                151.089                10.79            19.1
# 76770                151.089                10.79            19.1
# 76771                151.089                10.79            19.1
# ...                      ...                  ...             ...
# 77208                151.089                10.79            19.1
# 77209                151.089                10.79            19.1
# 77210                151.089                10.79            19.1
# 77211                151.089                10.79            19.1
# 77212                151.089                10.79            19.1
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 76767          24.6                     NaN                        2.77
# 76768          24.6                     NaN                        2.77
# 76769          24.6                     NaN                        2.77
# 76770          24.6                     NaN                        2.77
# 76771          24.6                     NaN                        2.77
# ...             ...                     ...                         ...
# 77208          24.6                     NaN                        2.77
# 77209          24.6                     NaN                        2.77
# 77210          24.6                     NaN                        2.77
# 77211          24.6                     NaN                        2.77
# 77212          24.6                     NaN                        2.77
#
#        life_expectancy  human_development_index
# 76767            78.86                    0.926
# 76768            78.86                    0.926
# 76769            78.86                    0.926
# 76770            78.86                    0.926
# 76771            78.86                    0.926
# ...                ...                      ...
# 77208            78.86                    0.926
# 77209            78.86                    0.926
# 77210            78.86                    0.926
# 77211            78.86                    0.926
# 77212            78.86                    0.926
#
# [446 rows x 59 columns]

# %%
# Date, total cases, new cases, and deaths data
covid_numbers_us_df = covid_data_df_us[["date","total_cases", "new_cases", "total_deaths", "new_deaths", "total_cases_per_million", "new_cases_per_million", "total_deaths_per_million", "new_deaths_per_million"]]
covid_numbers_us_df
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths  \
# 76767  2020-01-22          1.0        NaN           NaN         NaN
# 76768  2020-01-23          1.0        0.0           NaN         NaN
# 76769  2020-01-24          2.0        1.0           NaN         NaN
# 76770  2020-01-25          2.0        0.0           NaN         NaN
# 76771  2020-01-26          5.0        3.0           NaN         NaN
# ...           ...          ...        ...           ...         ...
# 77208  2021-04-07   30922386.0    75038.0      559202.0      2570.0
# 77209  2021-04-08   31002264.0    79878.0      560202.0      1000.0
# 77210  2021-04-09   31084962.0    82698.0      561074.0       872.0
# 77211  2021-04-10   31151495.0    66533.0      561783.0       709.0
# 77212  2021-04-11   31197873.0    46378.0      562066.0       283.0
#
#        total_cases_per_million  new_cases_per_million  \
# 76767                    0.003                    NaN
# 76768                    0.003                  0.000
# 76769                    0.006                  0.003
# 76770                    0.006                  0.000
# 76771                    0.015                  0.009
# ...                        ...                    ...
# 77208                93420.359                226.699
# 77209                93661.680                241.321
# 77210                93911.521                249.841
# 77211                94112.525                201.004
# 77212                94252.639                140.114
#
#        total_deaths_per_million  new_deaths_per_million
# 76767                       NaN                     NaN
# 76768                       NaN                     NaN
# 76769                       NaN                     NaN
# 76770                       NaN                     NaN
# 76771                       NaN                     NaN
# ...                         ...                     ...
# 77208                  1689.419                   7.764
# 77209                  1692.440                   3.021
# 77210                  1695.074                   2.634
# 77211                  1697.216                   2.142
# 77212                  1698.071                   0.855
#
# [446 rows x 9 columns]

# %%
# Test data
covid_testdata_df_us = covid_data_df_us[["date", "new_tests", "total_tests", "total_tests_per_thousand", "new_tests_per_thousand", "positive_rate", "tests_per_case"]]
# Keep only the rows with at least 2 non-NA values.
covid_testdata_df_us.dropna(thresh=2)
# Out:
#              date  new_tests  total_tests  total_tests_per_thousand  \
# 76806  2020-03-01      372.0        372.0                     0.001
# 76807  2020-03-02      550.0        922.0                     0.003
# 76808  2020-03-03      933.0       1855.0                     0.006
# 76809  2020-03-04      924.0       2779.0                     0.008
# 76810  2020-03-05     1205.0       3984.0                     0.012
# ...           ...        ...          ...                       ...
# 77203  2021-04-02  1210503.0  382758324.0                  1156.360
# 77204  2021-04-03   841444.0  383599768.0                  1158.902
# 77205  2021-04-04   450322.0  384050090.0                  1160.263
# 77206  2021-04-05   530002.0  384580092.0                  1161.864
# 77207  2021-04-06   484155.0  385064247.0                  1163.327
#
#        new_tests_per_thousand  positive_rate  tests_per_case
# 76806                   0.001            NaN             NaN
# 76807                   0.002            NaN             NaN
# 76808                   0.003            NaN             NaN
# 76809                   0.003            NaN             NaN
# 76810                   0.004            NaN             NaN
# ...                       ...            ...             ...
# 77203                   3.657          0.055            18.2
# 77204                   2.542          0.057            17.5
# 77205                   1.360          0.057            17.5
# 77206                   1.601          0.061            16.4
# 77207                   1.463          0.070            14.3
#
# [402 rows x 7 columns]

# %%
covid_data_state = "./resources/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv"

covid_data_state_df = pd.read_csv(covid_data_state, low_memory=False)

covid_data_state_df
# Out:
# D:\Usuarios\Javi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 0           2020-02       NaN              NaN        NaN               NaN
# 1           2020-02       NaN              NaN        NaN               NaN
# 2           2020-02       NaN              NaN        NaN               NaN
# 3           2020-08       NaN              NaN        NaN               NaN
# 4           2020-08       NaN              NaN        NaN               NaN
# ...             ...       ...              ...        ...               ...
# 22507134    2020-12        AZ              4.0       YUMA            4027.0
# 22507135    2020-12        AZ              4.0       YUMA            4027.0
# 22507136    2020-12        AZ              4.0       YUMA            4027.0
# 22507137    2020-12        AZ              4.0       YUMA            4027.0
# 22507138    2020-12        AZ              4.0       YUMA            4027.0
#
#           age_group   sex   race            ethnicity  \
# 0               NaN   NaN    NaN                  NaN
# 1               NaN   NaN    NaN                  NaN
# 2               NaN   NaN    NaN                  NaN
# 3               NaN   NaN    NaN                  NaN
# 4               NaN   NaN    NaN                  NaN
# ...             ...   ...    ...                  ...
# 22507134  65+ years  Male  White  Non-Hispanic/Latino
# 22507135  65+ years  Male  White  Non-Hispanic/Latino
# 22507136  65+ years  Male  White  Non-Hispanic/Latino
# 22507137  65+ years  Male  White  Non-Hispanic/Latino
# 22507138  65+ years  Male  White  Non-Hispanic/Latino
#
#           case_positive_specimen_interval  case_onset_interval  \
# 0                                     NaN                  0.0
# 1                                     3.0                  0.0
# 2                                     NaN                  0.0
# 3                                     0.0                  NaN
# 4                                     0.0                  NaN
# ...                                   ...                  ...
# 22507134                              NaN                  NaN
# 22507135                              NaN                  NaN
# 22507136                              NaN                  NaN
# 22507137                              NaN                  NaN
# 22507138                              NaN                  NaN
#
#                        process exposure_yn             current_status  \
# 0                      Missing     Missing  Laboratory-confirmed case
# 1          Clinical evaluation         Yes  Laboratory-confirmed case
# 2          Clinical evaluation     Missing  Laboratory-confirmed case
# 3         Routine surveillance     Missing  Laboratory-confirmed case
# 4         Routine surveillance     Missing  Laboratory-confirmed case
# ...                        ...         ...                        ...
# 22507134               Missing     Missing  Laboratory-confirmed case
# 22507135               Missing     Missing  Laboratory-confirmed case
# 22507136               Missing     Missing  Laboratory-confirmed case
# 22507137               Missing     Missing  Laboratory-confirmed case
# 22507138               Missing     Missing  Laboratory-confirmed case
#
#          symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0           Symptomatic      Yes  Missing      NaN                      NaN
# 1           Symptomatic      Yes      Yes      NaN                      Yes
# 2           Symptomatic      Yes       No      NaN                      Yes
# 3          Asymptomatic       No       No  Missing                      Yes
# 4               Missing  Missing  Missing  Missing                      Yes
# ...                 ...      ...      ...      ...                      ...
# 22507134        Missing      Yes  Missing      Yes                      NaN
# 22507135        Missing  Missing  Missing      Yes                      NaN
# 22507136        Missing      Yes  Missing      Yes                      NaN
# 22507137        Missing      Yes  Missing      Yes                      NaN
# 22507138        Missing      Yes  Missing      Yes                      NaN
#
# [22507139 rows x 19 columns]

# %%
# California data
covid_data_CA = covid_data_state_df.loc[covid_data_state_df["res_state"] == "CA"]
covid_data_CA
# Out:
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 205         2020-12        CA              6.0        NaN               NaN
# 206         2020-12        CA              6.0        NaN               NaN
# 207         2020-12        CA              6.0        NaN               NaN
# 7413        2020-03        CA              6.0      BUTTE            6007.0
# 7414        2020-03        CA              6.0      BUTTE            6007.0
# ...             ...       ...              ...        ...               ...
# 22506961    2020-12        CA              6.0       YOLO            6113.0
# 22506962    2020-12        CA              6.0       YOLO            6113.0
# 22506963    2020-12        CA              6.0       YOLO            6113.0
# 22506964    2020-12        CA              6.0       YOLO            6113.0
# 22506965    2020-12        CA              6.0       YOLO            6113.0
#
#           age_group   sex   race            ethnicity  \
# 205         Missing   NaN    NaN                  NaN
# 206         Missing   NaN    NaN                  NaN
# 207             NaN   NaN    NaN                  NaN
# 7413            NaN   NaN    NaN                  NaN
# 7414            NaN   NaN    NaN                  NaN
# ...             ...   ...    ...                  ...
# 22506961  65+ years  Male  White  Non-Hispanic/Latino
# 22506962  65+ years  Male  White  Non-Hispanic/Latino
# 22506963  65+ years  Male  White  Non-Hispanic/Latino
# 22506964  65+ years  Male  White  Non-Hispanic/Latino
# 22506965  65+ years  Male  White  Non-Hispanic/Latino
#
#           case_positive_specimen_interval  case_onset_interval  process  \
# 205                                   NaN                  0.0  Missing
# 206                                   NaN                  NaN  Missing
# 207                                   NaN                  0.0  Missing
# 7413                                  NaN                  0.0  Missing
# 7414                                  NaN                  0.0  Missing
# ...                                   ...                  ...      ...
# 22506961                              NaN                  NaN  Missing
# 22506962                              NaN                  0.0  Missing
# 22506963                              NaN                  NaN  Missing
# 22506964                              NaN                  NaN  Missing
# 22506965                              NaN                  NaN  Missing
#
#          exposure_yn             current_status symptom_status hosp_yn  \
# 205          Missing  Laboratory-confirmed case    Symptomatic     Yes
# 206          Missing  Laboratory-confirmed case        Unknown      No
# 207          Missing  Laboratory-confirmed case    Symptomatic     Yes
# 7413         Missing  Laboratory-confirmed case    Symptomatic      No
# 7414         Missing  Laboratory-confirmed case    Symptomatic     Yes
# ...              ...                        ...            ...     ...
# 22506961     Missing  Laboratory-confirmed case        Unknown      No
# 22506962     Missing  Laboratory-confirmed case    Symptomatic     Yes
# 22506963     Missing  Laboratory-confirmed case        Unknown     Yes
# 22506964     Missing  Laboratory-confirmed case        Unknown     Yes
# 22506965     Missing  Laboratory-confirmed case        Unknown     Yes
#
#            icu_yn death_yn underlying_conditions_yn
# 205       Missing      NaN                      NaN
# 206       Missing      NaN                      NaN
# 207       Unknown      NaN                      NaN
# 7413      Missing       No                      NaN
# 7414           No       No                      NaN
# ...           ...      ...                      ...
# 22506961  Missing      NaN                      NaN
# 22506962      Yes      NaN                      NaN
# 22506963      Yes      NaN                      NaN
# 22506964  Missing      NaN                      NaN
# 22506965  Missing      NaN                      NaN
#
# [3547519 rows x 19 columns]

# %% [markdown]
# ## COVID-19 Vactination Data

# %%
us_vaccination = "./resources/us_state_vaccinations.csv"

us_vaccination_df = pd.read_csv(us_vaccination)

us_vaccination_df
# Out:
#             date location  total_vaccinations  total_distributed  \
# 0     2021-01-12  Alabama             78134.0           377025.0
# 1     2021-01-13  Alabama             84040.0           378975.0
# 2     2021-01-14  Alabama             92300.0           435350.0
# 3     2021-01-15  Alabama            100567.0           444650.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 5933  2021-04-08  Wyoming            288814.0           436025.0
# 5934  2021-04-09  Wyoming            289028.0           447855.0
# 5935  2021-04-10  Wyoming            289340.0           450525.0
# 5936  2021-04-11  Wyoming            310702.0           450525.0
# 5937  2021-04-12  Wyoming            310765.0           450525.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# 1               74792.0                                 0.19
# 2               80480.0                                  NaN
# 3               86956.0                                 0.28
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 5933           169230.0                                20.75
# 5934           169409.0                                20.78
# 5935           169683.0                                20.83
# 5936           180223.0                                22.80
# 5937           180275.0                                22.81
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                               1.59                   7270.0
# 1                               1.71                   9245.0
# 2                               1.88                      NaN
# 3                               2.05                  13488.0
# 4                                NaN                      NaN
# ...                              ...                      ...
# 5933                           49.90                 120094.0
# 5934                           49.94                 120246.0
# 5935                           49.99                 120534.0
# 5936                           53.68                 131933.0
# 5937                           53.70                 131994.0
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                              1.45                     7.69
# 1                              1.53                     7.73
# 2                              1.64                     8.88
# 3                              1.77                     9.07
# 4                               NaN                      NaN
# ...                             ...                      ...
# 5933                          29.24                    75.34
# 5934                          29.27                    77.38
# 5935                          29.32                    77.84
# 5936                          31.14                    77.84
# 5937                          31.15                    77.84
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                 NaN
# 1                     5906.0              5906.0
# 2                     8260.0              7083.0
# 3                     8267.0              7478.0
# 4                     7557.0              7498.0
# ...                      ...                 ...
# 5933                   228.0              2655.0
# 5934                   214.0              2633.0
# 5935                   312.0              2640.0
# 5936                 21362.0              3431.0
# 5937                    63.0              3400.0
#
#       daily_vaccinations_per_million  share_doses_used
# 0                                NaN             0.207
# 1                             1205.0             0.222
# 2                             1445.0             0.212
# 3                             1525.0             0.226
# 4                             1529.0               NaN
# ...                              ...               ...
# 5933                          4587.0             0.662
# 5934                          4549.0             0.645
# 5935                          4561.0             0.642
# 5936                          5928.0             0.690
# 5937                          5875.0             0.690
#
# [5938 rows x 14 columns]

# %%
ca_us_vaccination_df = us_vaccination_df.loc[us_vaccination_df["location"] == "California"]
ca_us_vaccination_df
# Out:
#            date    location  total_vaccinations  total_distributed  \
# 546  2021-01-12  California            816301.0          3286050.0
# 547  2021-01-13  California            891489.0          3435650.0
# 548  2021-01-14  California            975293.0          3540175.0
# 549  2021-01-15  California           1072959.0          3548575.0
# 550  2021-01-16  California                 NaN                NaN
# ..          ...         ...                 ...                ...
# 632  2021-04-08  California          21243518.0         27861050.0
# 633  2021-04-09  California          21725654.0         28532520.0
# 634  2021-04-10  California          22281619.0         29034050.0
# 635  2021-04-11  California          22754163.0         29034050.0
# 636  2021-04-12  California          23031055.0         29034050.0
#
#      people_vaccinated  people_fully_vaccinated_per_hundred  \
# 546           703540.0                                 0.25
# 547           744545.0                                 0.34
# 548           801998.0                                  NaN
# 549           865387.0                                 0.52
# 550                NaN                                  NaN
# ..                 ...                                  ...
# 632         14123008.0                                19.23
# 633         14445185.0                                19.80
# 634         14803675.0                                20.53
# 635         15123816.0                                21.09
# 636         15320888.0                                21.41
#
#      total_vaccinations_per_hundred  people_fully_vaccinated  \
# 546                            2.07                 100089.0
# 547                            2.26                 133689.0
# 548                            2.47                      NaN
# 549                            2.72                 204374.0
# 550                             NaN                      NaN
# ..                              ...                      ...
# 632                           53.76                7599559.0
# 633                           54.98                7822226.0
# 634                           56.39                8110488.0
# 635                           57.59                8332396.0
# 636                           58.29                8459357.0
#
#      people_vaccinated_per_hundred  distributed_per_hundred  \
# 546                           1.78                     8.32
# 547                           1.88                     8.70
# 548                           2.03                     8.96
# 549                           2.19                     8.98
# 550                            NaN                      NaN
# ..                             ...                      ...
# 632                          35.74                    70.51
# 633                          36.56                    72.21
# 634                          37.47                    73.48
# 635                          38.28                    73.48
# 636                          38.78                    73.48
#
#      daily_vaccinations_raw  daily_vaccinations  \
# 546                     NaN                 NaN
# 547                75188.00             75188.0
# 548                83804.00             79496.0
# 549                97666.00             85553.0
# 550                96867.75             88381.0
# ..                      ...                 ...
# 632               377626.00            377051.0
# 633               482136.00            391393.0
# 634               555965.00            404572.0
# 635               472544.00            398820.0
# 636               276892.00            388844.0
#
#      daily_vaccinations_per_million  share_doses_used
# 546                             NaN             0.248
# 547                          1903.0             0.259
# 548                          2012.0             0.275
# 549                          2165.0             0.302
# 550                          2237.0               NaN
# ..                              ...               ...
# 632                          9543.0             0.762
# 633                          9906.0             0.761
# 634                         10239.0             0.767
# 635                         10094.0             0.784
# 636                          9841.0             0.793
#
# [91 rows x 14 columns]

# %%
vaccination_by_man = "./resources/vaccinations-by-manufacturer.csv"

vaccination_by_man_df = pd.read_csv(vaccination_by_man)

vaccination_by_man_df
# Out:
#            location        date          vaccine  total_vaccinations
# 0             Chile  2020-12-24  Pfizer/BioNTech                 420
# 1             Chile  2020-12-25  Pfizer/BioNTech                5198
# 2             Chile  2020-12-26  Pfizer/BioNTech                8338
# 3             Chile  2020-12-27  Pfizer/BioNTech                8649
# 4             Chile  2020-12-28  Pfizer/BioNTech                8649
# ...             ...         ...              ...                 ...
# 2261  United States  2021-04-10          Moderna            82622178
# 2262  United States  2021-04-10  Pfizer/BioNTech            94715143
# 2263  United States  2021-04-11  Johnson&Johnson             6453740
# 2264  United States  2021-04-11          Moderna            83847244
# 2265  United States  2021-04-11  Pfizer/BioNTech            96586783
#
# [2266 rows x 4 columns]

# %%
vaccination_by_man_us_df =  vaccination_by_man_df.loc[vaccination_by_man_df["location"] == "United States"]
vaccination_by_man_us_df
# Out:
#            location        date          vaccine  total_vaccinations
# 2061  United States  2021-01-12          Moderna             3835859
# 2062  United States  2021-01-12  Pfizer/BioNTech             5488697
# 2063  United States  2021-01-13          Moderna             4249795
# 2064  United States  2021-01-13  Pfizer/BioNTech             6025872
# 2065  United States  2021-01-15          Moderna             5122662
# ...             ...         ...              ...                 ...
# 2261  United States  2021-04-10          Moderna            82622178
# 2262  United States  2021-04-10  Pfizer/BioNTech            94715143
# 2263  United States  2021-04-11  Johnson&Johnson             6453740
# 2264  United States  2021-04-11          Moderna            83847244
# 2265  United States  2021-04-11  Pfizer/BioNTech            96586783
#
# [205 rows x 4 columns]
