# %% [markdown]
# # COVID-19 ETL
#
# This notebook is used to load, clean COVID-19 data and export it to PostgreSQL. The data contains:
#
# * Data on COVID-19 (coronavirus) by Our World in Data: https://github.com/owid/covid-19-data/tree/master/public/data
# * Data on COVID-19 (coronavirus) vaccinations by Our World in Data: https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations
# * COVID-19 Case Surveillance Public Use Data with Geography: https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Global COVID-19 Data
# The goal of this part is to divide the global data set into 3 parts:
# * Stats vs Cases data
# * Stats vs Tests data
# * Stats vs Vaccines data
#
# At the end of each part there will be a clean dataframe that will be uploaded to PostgreSQL.

# %%
covid_data = "./resources/owid-covid-data.csv"

covid_data_df = pd.read_csv(covid_data)
covid_data_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24        1.000      1.000
# 1          AFG      Asia  Afghanistan  2020-02-25        1.000      0.000
# 2          AFG      Asia  Afghanistan  2020-02-26        1.000      0.000
# 3          AFG      Asia  Afghanistan  2020-02-27        1.000      0.000
# 4          AFG      Asia  Afghanistan  2020-02-28        1.000      0.000
# ...        ...       ...          ...         ...          ...        ...
# 80981      ZWE    Africa     Zimbabwe  2021-04-07    36984.000     18.000
# 80982      ZWE    Africa     Zimbabwe  2021-04-08    37052.000     68.000
# 80983      ZWE    Africa     Zimbabwe  2021-04-09    37147.000     95.000
# 80984      ZWE    Africa     Zimbabwe  2021-04-10    37273.000    126.000
# 80985      ZWE    Africa     Zimbabwe  2021-04-11    37288.000     15.000
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     nan           nan         nan                  nan  ...
# 1                     nan           nan         nan                  nan  ...
# 2                     nan           nan         nan                  nan  ...
# 3                     nan           nan         nan                  nan  ...
# 4                     nan           nan         nan                  nan  ...
# ...                   ...           ...         ...                  ...  ...
# 80981              14.571      1531.000       0.000                1.143  ...
# 80982              22.286      1532.000       1.000                1.286  ...
# 80983              34.857      1535.000       3.000                1.571  ...
# 80984              51.714      1538.000       3.000                2.000  ...
# 80985              52.143      1538.000       0.000                1.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              nan                597.029
# 1            1803.987              nan                597.029
# 2            1803.987              nan                597.029
# 3            1803.987              nan                597.029
# 4            1803.987              nan                597.029
# ...               ...              ...                    ...
# 80981        1899.775           21.400                307.846
# 80982        1899.775           21.400                307.846
# 80983        1899.775           21.400                307.846
# 80984        1899.775           21.400                307.846
# 80985        1899.775           21.400                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                    9.590             nan           nan
# 1                    9.590             nan           nan
# 2                    9.590             nan           nan
# 3                    9.590             nan           nan
# 4                    9.590             nan           nan
# ...                    ...             ...           ...
# 80981                1.820           1.600        30.700
# 80982                1.820           1.600        30.700
# 80983                1.820           1.600        30.700
# 80984                1.820           1.600        30.700
# 80985                1.820           1.600        30.700
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                       0.500           64.830
# 1                      37.746                       0.500           64.830
# 2                      37.746                       0.500           64.830
# 3                      37.746                       0.500           64.830
# 4                      37.746                       0.500           64.830
# ...                       ...                         ...              ...
# 80981                  36.791                       1.700           61.490
# 80982                  36.791                       1.700           61.490
# 80983                  36.791                       1.700           61.490
# 80984                  36.791                       1.700           61.490
# 80985                  36.791                       1.700           61.490
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 80981                    0.571
# 80982                    0.571
# 80983                    0.571
# 80984                    0.571
# 80985                    0.571
#
# [80986 rows x 59 columns]

# %% [markdown]
# ## Global Stats vs Cases data

# %%
# Supress scientific notation by forcing formatting 
pd.options.display.float_format = '{:.3f}'.format

# Unefficient way of finding the last row of each country and inserting it into a new dataframe
# Ideally, making a list and appending it to a new dataframe would be much more efficient
# But there are so many columns that time-wise this takes less time

countries = covid_data_df["location"].unique().tolist()
stats = pd.DataFrame()
df = pd.DataFrame()

# Make dataframe from the total number of cases
for country in countries:
    df = covid_data_df.loc[covid_data_df["location"] == country]
    num_cases = df["total_cases"].argmax()
    df = df.iloc[num_cases].to_frame().T
    stats = pd.concat([stats,df])
    
del df

# %%
# Dataframe to be used for scatter plots - needs some cleaning (probably) 
# la forma de buscar pordria ser usando max en vez del ultimo de la fila, dependiendo de la columna en la que se haga 
stats = stats.dropna(subset=['total_cases'])
stats
# Habria que hacer tests vs stats y vaccines vs stats
# Out:
#        iso_code continent     location        date  total_cases new_cases  \
# 412         AFG      Asia  Afghanistan  2021-04-11     57160.00     16.00
# 836    OWID_AFR       NaN       Africa  2021-04-11   4350198.00   9684.00
# 1248        ALB    Europe      Albania  2021-04-11    128393.00    238.00
# 1660        DZA    Africa      Algeria  2021-04-11    118516.00    138.00
# 2066        AND    Europe      Andorra  2021-04-11     12545.00     48.00
# ...         ...       ...          ...         ...          ...       ...
# 79394       VNM      Asia      Vietnam  2021-04-11      2693.00      1.00
# 79840  OWID_WRL       NaN        World  2021-04-11 136046624.00 690739.00
# 80207       YEM      Asia        Yemen  2021-04-11      5357.00     81.00
# 80597       ZMB    Africa       Zambia  2021-04-11     90029.00    111.00
# 80985       ZWE    Africa     Zimbabwe  2021-04-11     37288.00     15.00
#
#       new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 412                69.14      2521.00       0.00                3.43  ...
# 836             11325.57    115710.00     288.00              265.29  ...
# 1248              266.00      2317.00       7.00                7.43  ...
# 1660              127.71      3130.00       4.00                3.57  ...
# 2066               44.86       120.00       0.00                0.43  ...
# ...                  ...          ...        ...                 ...  ...
# 79394               8.86        35.00       0.00                0.00  ...
# 79840          674669.29   2936364.00    8557.00            11871.00  ...
# 80207              79.86      1049.00      18.00               14.71  ...
# 80597             157.00      1226.00       0.00                0.86  ...
# 80985              52.14      1538.00       0.00                1.86  ...
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate  \
# 412          1803.99             NaN                597.03
# 836              NaN             NaN                   NaN
# 1248        11803.43            1.10                304.19
# 1660        13913.84            0.50                278.36
# 2066             NaN             NaN                109.14
# ...              ...             ...                   ...
# 79394        6171.88            2.00                245.47
# 79840       15469.21           10.00                233.07
# 80207        1479.15           18.80                495.00
# 80597        3689.25           57.50                234.50
# 80985        1899.78           21.40                307.85
#
#       diabetes_prevalence female_smokers male_smokers handwashing_facilities  \
# 412                  9.59            NaN          NaN                  37.75
# 836                   NaN            NaN          NaN                    NaN
# 1248                10.08           7.10        51.20                    NaN
# 1660                 6.73           0.70        30.40                  83.74
# 2066                 7.97          29.00        37.80                    NaN
# ...                   ...            ...          ...                    ...
# 79394                6.00           1.00        45.90                  85.85
# 79840                8.51           6.43        34.63                  60.13
# 80207                5.35           7.60        29.20                  49.54
# 80597                3.94           3.10        24.70                  13.94
# 80985                1.82           1.60        30.70                  36.79
#
#       hospital_beds_per_thousand life_expectancy human_development_index
# 412                         0.50           64.83                    0.51
# 836                          NaN             NaN                     NaN
# 1248                        2.89           78.57                    0.80
# 1660                        1.90           76.88                    0.75
# 2066                         NaN           83.73                    0.87
# ...                          ...             ...                     ...
# 79394                       2.60           75.40                    0.70
# 79840                       2.71           72.58                    0.74
# 80207                       0.70           66.12                    0.47
# 80597                       2.00           63.89                    0.58
# 80985                       1.70           61.49                    0.57
#
# [199 rows x 59 columns]

# %%
# Total cases vs stats
countries_stats = stats[["iso_code", "continent", "location", "total_cases", "population", "population_density", "median_age", "aged_65_older", "aged_70_older", "gdp_per_capita", "extreme_poverty", "cardiovasc_death_rate"]]
countries_stats
# Out:
#        iso_code continent     location  total_cases    population  \
# 412         AFG      Asia  Afghanistan     57160.00   38928341.00
# 836    OWID_AFR       NaN       Africa   4350198.00 1340598113.00
# 1248        ALB    Europe      Albania    128393.00    2877800.00
# 1660        DZA    Africa      Algeria    118516.00   43851043.00
# 2066        AND    Europe      Andorra     12545.00      77265.00
# ...         ...       ...          ...          ...           ...
# 79394       VNM      Asia      Vietnam      2693.00   97338583.00
# 79840  OWID_WRL       NaN        World 136046624.00 7794798729.00
# 80207       YEM      Asia        Yemen      5357.00   29825968.00
# 80597       ZMB    Africa       Zambia     90029.00   18383956.00
# 80985       ZWE    Africa     Zimbabwe     37288.00   14862927.00
#
#       population_density median_age aged_65_older aged_70_older  \
# 412                54.42      18.60          2.58          1.34
# 836                  NaN        NaN           NaN           NaN
# 1248              104.87      38.00         13.19          8.64
# 1660               17.35      29.10          6.21          3.86
# 2066              163.75        NaN           NaN           NaN
# ...                  ...        ...           ...           ...
# 79394             308.13      32.60          7.15          4.72
# 79840              58.05      30.90          8.70          5.36
# 80207              53.51      20.30          2.92          1.58
# 80597              23.00      17.70          2.48          1.54
# 80985              42.73      19.60          2.82          1.88
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate
# 412          1803.99             NaN                597.03
# 836              NaN             NaN                   NaN
# 1248        11803.43            1.10                304.19
# 1660        13913.84            0.50                278.36
# 2066             NaN             NaN                109.14
# ...              ...             ...                   ...
# 79394        6171.88            2.00                245.47
# 79840       15469.21           10.00                233.07
# 80207        1479.15           18.80                495.00
# 80597        3689.25           57.50                234.50
# 80985        1899.78           21.40                307.85
#
# [199 rows x 12 columns]

# %%
# Total cases vs more stats
more_countries_stats = stats[["iso_code", "continent", "location", "total_cases", "diabetes_prevalence", "female_smokers", "male_smokers", "hospital_beds_per_thousand", "life_expectancy", "human_development_index"]]
more_countries_stats
# Out:
#        iso_code continent     location  total_cases diabetes_prevalence  \
# 412         AFG      Asia  Afghanistan     57160.00                9.59
# 836    OWID_AFR       NaN       Africa   4350198.00                 NaN
# 1248        ALB    Europe      Albania    128393.00               10.08
# 1660        DZA    Africa      Algeria    118516.00                6.73
# 2066        AND    Europe      Andorra     12545.00                7.97
# ...         ...       ...          ...          ...                 ...
# 79394       VNM      Asia      Vietnam      2693.00                6.00
# 79840  OWID_WRL       NaN        World 136046624.00                8.51
# 80207       YEM      Asia        Yemen      5357.00                5.35
# 80597       ZMB    Africa       Zambia     90029.00                3.94
# 80985       ZWE    Africa     Zimbabwe     37288.00                1.82
#
#       female_smokers male_smokers hospital_beds_per_thousand life_expectancy  \
# 412              NaN          NaN                       0.50           64.83
# 836              NaN          NaN                        NaN             NaN
# 1248            7.10        51.20                       2.89           78.57
# 1660            0.70        30.40                       1.90           76.88
# 2066           29.00        37.80                        NaN           83.73
# ...              ...          ...                        ...             ...
# 79394           1.00        45.90                       2.60           75.40
# 79840           6.43        34.63                       2.71           72.58
# 80207           7.60        29.20                       0.70           66.12
# 80597           3.10        24.70                       2.00           63.89
# 80985           1.60        30.70                       1.70           61.49
#
#       human_development_index
# 412                      0.51
# 836                       NaN
# 1248                     0.80
# 1660                     0.75
# 2066                     0.87
# ...                       ...
# 79394                    0.70
# 79840                    0.74
# 80207                    0.47
# 80597                    0.58
# 80985                    0.57
#
# [199 rows x 10 columns]

# %%
merged_country_stats = countries_stats.merge(more_countries_stats, how="inner", on=["iso_code","continent","location","total_cases"])
merged_country_stats
# Out:
#      iso_code continent     location  total_cases    population  \
# 0         AFG      Asia  Afghanistan     57160.00   38928341.00
# 1    OWID_AFR       NaN       Africa   4350198.00 1340598113.00
# 2         ALB    Europe      Albania    128393.00    2877800.00
# 3         DZA    Africa      Algeria    118516.00   43851043.00
# 4         AND    Europe      Andorra     12545.00      77265.00
# ..        ...       ...          ...          ...           ...
# 194       VNM      Asia      Vietnam      2693.00   97338583.00
# 195  OWID_WRL       NaN        World 136046624.00 7794798729.00
# 196       YEM      Asia        Yemen      5357.00   29825968.00
# 197       ZMB    Africa       Zambia     90029.00   18383956.00
# 198       ZWE    Africa     Zimbabwe     37288.00   14862927.00
#
#     population_density median_age aged_65_older aged_70_older gdp_per_capita  \
# 0                54.42      18.60          2.58          1.34        1803.99
# 1                  NaN        NaN           NaN           NaN            NaN
# 2               104.87      38.00         13.19          8.64       11803.43
# 3                17.35      29.10          6.21          3.86       13913.84
# 4               163.75        NaN           NaN           NaN            NaN
# ..                 ...        ...           ...           ...            ...
# 194             308.13      32.60          7.15          4.72        6171.88
# 195              58.05      30.90          8.70          5.36       15469.21
# 196              53.51      20.30          2.92          1.58        1479.15
# 197              23.00      17.70          2.48          1.54        3689.25
# 198              42.73      19.60          2.82          1.88        1899.78
#
#     extreme_poverty cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 0               NaN                597.03                9.59            NaN
# 1               NaN                   NaN                 NaN            NaN
# 2              1.10                304.19               10.08           7.10
# 3              0.50                278.36                6.73           0.70
# 4               NaN                109.14                7.97          29.00
# ..              ...                   ...                 ...            ...
# 194            2.00                245.47                6.00           1.00
# 195           10.00                233.07                8.51           6.43
# 196           18.80                495.00                5.35           7.60
# 197           57.50                234.50                3.94           3.10
# 198           21.40                307.85                1.82           1.60
#
#     male_smokers hospital_beds_per_thousand life_expectancy  \
# 0            NaN                       0.50           64.83
# 1            NaN                        NaN             NaN
# 2          51.20                       2.89           78.57
# 3          30.40                       1.90           76.88
# 4          37.80                        NaN           83.73
# ..           ...                        ...             ...
# 194        45.90                       2.60           75.40
# 195        34.63                       2.71           72.58
# 196        29.20                       0.70           66.12
# 197        24.70                       2.00           63.89
# 198        30.70                       1.70           61.49
#
#     human_development_index
# 0                      0.51
# 1                       NaN
# 2                      0.80
# 3                      0.75
# 4                      0.87
# ..                      ...
# 194                    0.70
# 195                    0.74
# 196                    0.47
# 197                    0.58
# 198                    0.57
#
# [199 rows x 18 columns]

# %%
# Global cases data 
stats_cases = stats[["iso_code", "continent", "location", "total_cases", "total_deaths", "total_cases_per_million", "total_deaths_per_million"]]
stats_cases
# Out:
#        iso_code continent     location  total_cases total_deaths  \
# 412         AFG      Asia  Afghanistan     57160.00      2521.00
# 836    OWID_AFR       NaN       Africa   4350198.00    115710.00
# 1248        ALB    Europe      Albania    128393.00      2317.00
# 1660        DZA    Africa      Algeria    118516.00      3130.00
# 2066        AND    Europe      Andorra     12545.00       120.00
# ...         ...       ...          ...          ...          ...
# 79394       VNM      Asia      Vietnam      2693.00        35.00
# 79840  OWID_WRL       NaN        World 136046624.00   2936364.00
# 80207       YEM      Asia        Yemen      5357.00      1049.00
# 80597       ZMB    Africa       Zambia     90029.00      1226.00
# 80985       ZWE    Africa     Zimbabwe     37288.00      1538.00
#
#       total_cases_per_million total_deaths_per_million
# 412                   1468.34                    64.76
# 836                   3244.97                    86.31
# 1248                 44614.98                   805.13
# 1660                  2702.70                    71.38
# 2066                162363.30                  1553.10
# ...                       ...                      ...
# 79394                   27.67                     0.36
# 79840                17453.51                   376.71
# 80207                  179.61                    35.17
# 80597                 4897.15                    66.69
# 80985                 2508.79                   103.48
#
# [199 rows x 7 columns]

# %%
# Final dataframe for cases vs stats
ready_stats_vs_cases = merged_country_stats.merge(stats_cases, how="inner", on=["iso_code","continent","location","total_cases"])
ready_stats_vs_cases
# Out:
#      iso_code continent     location  total_cases    population  \
# 0         AFG      Asia  Afghanistan     57160.00   38928341.00
# 1    OWID_AFR       NaN       Africa   4350198.00 1340598113.00
# 2         ALB    Europe      Albania    128393.00    2877800.00
# 3         DZA    Africa      Algeria    118516.00   43851043.00
# 4         AND    Europe      Andorra     12545.00      77265.00
# ..        ...       ...          ...          ...           ...
# 194       VNM      Asia      Vietnam      2693.00   97338583.00
# 195  OWID_WRL       NaN        World 136046624.00 7794798729.00
# 196       YEM      Asia        Yemen      5357.00   29825968.00
# 197       ZMB    Africa       Zambia     90029.00   18383956.00
# 198       ZWE    Africa     Zimbabwe     37288.00   14862927.00
#
#     population_density median_age aged_65_older aged_70_older gdp_per_capita  \
# 0                54.42      18.60          2.58          1.34        1803.99
# 1                  NaN        NaN           NaN           NaN            NaN
# 2               104.87      38.00         13.19          8.64       11803.43
# 3                17.35      29.10          6.21          3.86       13913.84
# 4               163.75        NaN           NaN           NaN            NaN
# ..                 ...        ...           ...           ...            ...
# 194             308.13      32.60          7.15          4.72        6171.88
# 195              58.05      30.90          8.70          5.36       15469.21
# 196              53.51      20.30          2.92          1.58        1479.15
# 197              23.00      17.70          2.48          1.54        3689.25
# 198              42.73      19.60          2.82          1.88        1899.78
#
#      ... cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 0    ...                597.03                9.59            NaN
# 1    ...                   NaN                 NaN            NaN
# 2    ...                304.19               10.08           7.10
# 3    ...                278.36                6.73           0.70
# 4    ...                109.14                7.97          29.00
# ..   ...                   ...                 ...            ...
# 194  ...                245.47                6.00           1.00
# 195  ...                233.07                8.51           6.43
# 196  ...                495.00                5.35           7.60
# 197  ...                234.50                3.94           3.10
# 198  ...                307.85                1.82           1.60
#
#     male_smokers hospital_beds_per_thousand life_expectancy  \
# 0            NaN                       0.50           64.83
# 1            NaN                        NaN             NaN
# 2          51.20                       2.89           78.57
# 3          30.40                       1.90           76.88
# 4          37.80                        NaN           83.73
# ..           ...                        ...             ...
# 194        45.90                       2.60           75.40
# 195        34.63                       2.71           72.58
# 196        29.20                       0.70           66.12
# 197        24.70                       2.00           63.89
# 198        30.70                       1.70           61.49
#
#     human_development_index total_deaths total_cases_per_million  \
# 0                      0.51      2521.00                 1468.34
# 1                       NaN    115710.00                 3244.97
# 2                      0.80      2317.00                44614.98
# 3                      0.75      3130.00                 2702.70
# 4                      0.87       120.00               162363.30
# ..                      ...          ...                     ...
# 194                    0.70        35.00                   27.67
# 195                    0.74   2936364.00                17453.51
# 196                    0.47      1049.00                  179.61
# 197                    0.58      1226.00                 4897.15
# 198                    0.57      1538.00                 2508.79
#
#     total_deaths_per_million
# 0                      64.76
# 1                      86.31
# 2                     805.13
# 3                      71.38
# 4                    1553.10
# ..                       ...
# 194                     0.36
# 195                   376.71
# 196                    35.17
# 197                    66.69
# 198                   103.48
#
# [199 rows x 21 columns]

# %% [markdown]
# ## Global Stats vs Test data

# %%
# Iterate through each country, find the max numer of tests done and concatenate to new dataframe
test_stats = pd.DataFrame()
df = pd.DataFrame()

for country in countries:
    df = covid_data_df.loc[covid_data_df["location"] == country]
    num_tests = df["total_tests"].argmax()
    df = df.iloc[num_tests].to_frame().T
    test_stats = pd.concat([test_stats,df])

del df

# %%
# Global test data
# Drop NaN and get test columns 
test_stats = test_stats.dropna(subset=['total_tests'])
test_stats_df = test_stats[["iso_code", "continent", "location", "new_tests", "total_tests", "total_tests_per_thousand", "new_tests_per_thousand", "positive_rate", "tests_per_case", "tests_units"]]
test_stats_df
# Out:
#       iso_code      continent       location new_tests  total_tests  \
# 1244       ALB         Europe        Albania   2538.00    555376.00
# 2060       AND         Europe        Andorra       NaN    171485.00
# 3352       ARG  South America      Argentina  32157.00   7610064.00
# 3764       ARM           Asia        Armenia   4943.00    889872.00
# 4652       AUS        Oceania      Australia  44549.00  15998167.00
# ...        ...            ...            ...       ...          ...
# 77207      USA  North America  United States 484155.00 385064247.00
# 77604      URY  South America        Uruguay       NaN   1488362.00
# 79367      VNM           Asia        Vietnam       NaN   2482302.00
# 80594      ZMB         Africa         Zambia   6016.00   1286686.00
# 80981      ZWE         Africa       Zimbabwe   3301.00    449264.00
#
#       total_tests_per_thousand new_tests_per_thousand positive_rate  \
# 1244                    192.99                   0.88          0.11
# 2060                   2219.44                    NaN          0.12
# 3352                    168.38                   0.71          0.23
# 3764                    300.30                   1.67          0.21
# 4652                    627.38                   1.75          0.00
# ...                        ...                    ...           ...
# 77207                  1163.33                   1.46          0.07
# 77604                   428.46                    NaN          0.22
# 79367                    25.50                    NaN           NaN
# 80594                    69.99                   0.33          0.04
# 80981                    30.23                   0.22          0.01
#
#       tests_per_case      tests_units
# 1244            9.20  tests performed
# 2060            8.10    people tested
# 3352            4.40  tests performed
# 3764            4.70  tests performed
# 4652         5250.40  tests performed
# ...              ...              ...
# 77207          14.30  tests performed
# 77604           4.50  tests performed
# 79367            NaN   samples tested
# 80594          28.00  tests performed
# 80981         117.40  tests performed
#
# [113 rows x 10 columns]

# %%
# Stats to merge with test data 
more_test_stats = test_stats[["iso_code", "continent", "location", "total_tests", "population", "population_density", "median_age", "aged_65_older", "aged_70_older", "gdp_per_capita", "extreme_poverty", "cardiovasc_death_rate", "diabetes_prevalence", "female_smokers", "male_smokers", "hospital_beds_per_thousand", "life_expectancy", "human_development_index"]]
more_test_stats
# Out:
#       iso_code      continent       location  total_tests   population  \
# 1244       ALB         Europe        Albania    555376.00   2877800.00
# 2060       AND         Europe        Andorra    171485.00     77265.00
# 3352       ARG  South America      Argentina   7610064.00  45195777.00
# 3764       ARM           Asia        Armenia    889872.00   2963234.00
# 4652       AUS        Oceania      Australia  15998167.00  25499881.00
# ...        ...            ...            ...          ...          ...
# 77207      USA  North America  United States 385064247.00 331002647.00
# 77604      URY  South America        Uruguay   1488362.00   3473727.00
# 79367      VNM           Asia        Vietnam   2482302.00  97338583.00
# 80594      ZMB         Africa         Zambia   1286686.00  18383956.00
# 80981      ZWE         Africa       Zimbabwe    449264.00  14862927.00
#
#       population_density median_age aged_65_older aged_70_older  \
# 1244              104.87      38.00         13.19          8.64
# 2060              163.75        NaN           NaN           NaN
# 3352               16.18      31.90         11.20          7.44
# 3764              102.93      35.70         11.23          7.57
# 4652                3.20      37.90         15.50         10.13
# ...                  ...        ...           ...           ...
# 77207              35.61      38.30         15.41          9.73
# 77604              19.75      35.60         14.65         10.36
# 79367             308.13      32.60          7.15          4.72
# 80594              23.00      17.70          2.48          1.54
# 80981              42.73      19.60          2.82          1.88
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate  \
# 1244        11803.43            1.10                304.19
# 2060             NaN             NaN                109.14
# 3352        18933.91            0.60                191.03
# 3764         8787.58            1.80                341.01
# 4652        44648.71            0.50                107.79
# ...              ...             ...                   ...
# 77207       54225.45            1.20                151.09
# 77604       20551.41            0.10                160.71
# 79367        6171.88            2.00                245.47
# 80594        3689.25           57.50                234.50
# 80981        1899.78           21.40                307.85
#
#       diabetes_prevalence female_smokers male_smokers  \
# 1244                10.08           7.10        51.20
# 2060                 7.97          29.00        37.80
# 3352                 5.50          16.20        27.70
# 3764                 7.11           1.50        52.10
# 4652                 5.07          13.00        16.50
# ...                   ...            ...          ...
# 77207               10.79          19.10        24.60
# 77604                6.93          14.00        19.90
# 79367                6.00           1.00        45.90
# 80594                3.94           3.10        24.70
# 80981                1.82           1.60        30.70
#
#       hospital_beds_per_thousand life_expectancy human_development_index
# 1244                        2.89           78.57                    0.80
# 2060                         NaN           83.73                    0.87
# 3352                        5.00           76.67                    0.84
# 3764                        4.20           75.09                    0.78
# 4652                        3.84           83.44                    0.94
# ...                          ...             ...                     ...
# 77207                       2.77           78.86                    0.93
# 77604                       2.80           77.91                    0.82
# 79367                       2.60           75.40                    0.70
# 80594                       2.00           63.89                    0.58
# 80981                       1.70           61.49                    0.57
#
# [113 rows x 18 columns]

# %%
# Final dataframe for test vs stats
ready_test_stats = test_stats_df.merge(more_test_stats, how="inner", on=["iso_code","continent","location","total_tests"])
ready_test_stats
# Out:
#     iso_code      continent       location new_tests  total_tests  \
# 0        ALB         Europe        Albania   2538.00    555376.00
# 1        AND         Europe        Andorra       NaN    171485.00
# 2        ARG  South America      Argentina  32157.00   7610064.00
# 3        ARM           Asia        Armenia   4943.00    889872.00
# 4        AUS        Oceania      Australia  44549.00  15998167.00
# ..       ...            ...            ...       ...          ...
# 108      USA  North America  United States 484155.00 385064247.00
# 109      URY  South America        Uruguay       NaN   1488362.00
# 110      VNM           Asia        Vietnam       NaN   2482302.00
# 111      ZMB         Africa         Zambia   6016.00   1286686.00
# 112      ZWE         Africa       Zimbabwe   3301.00    449264.00
#
#     total_tests_per_thousand new_tests_per_thousand positive_rate  \
# 0                     192.99                   0.88          0.11
# 1                    2219.44                    NaN          0.12
# 2                     168.38                   0.71          0.23
# 3                     300.30                   1.67          0.21
# 4                     627.38                   1.75          0.00
# ..                       ...                    ...           ...
# 108                  1163.33                   1.46          0.07
# 109                   428.46                    NaN          0.22
# 110                    25.50                    NaN           NaN
# 111                    69.99                   0.33          0.04
# 112                    30.23                   0.22          0.01
#
#     tests_per_case      tests_units  ... aged_70_older gdp_per_capita  \
# 0             9.20  tests performed  ...          8.64       11803.43
# 1             8.10    people tested  ...           NaN            NaN
# 2             4.40  tests performed  ...          7.44       18933.91
# 3             4.70  tests performed  ...          7.57        8787.58
# 4          5250.40  tests performed  ...         10.13       44648.71
# ..             ...              ...  ...           ...            ...
# 108          14.30  tests performed  ...          9.73       54225.45
# 109           4.50  tests performed  ...         10.36       20551.41
# 110            NaN   samples tested  ...          4.72        6171.88
# 111          28.00  tests performed  ...          1.54        3689.25
# 112         117.40  tests performed  ...          1.88        1899.78
#
#     extreme_poverty cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 0              1.10                304.19               10.08           7.10
# 1               NaN                109.14                7.97          29.00
# 2              0.60                191.03                5.50          16.20
# 3              1.80                341.01                7.11           1.50
# 4              0.50                107.79                5.07          13.00
# ..              ...                   ...                 ...            ...
# 108            1.20                151.09               10.79          19.10
# 109            0.10                160.71                6.93          14.00
# 110            2.00                245.47                6.00           1.00
# 111           57.50                234.50                3.94           3.10
# 112           21.40                307.85                1.82           1.60
#
#     male_smokers hospital_beds_per_thousand life_expectancy  \
# 0          51.20                       2.89           78.57
# 1          37.80                        NaN           83.73
# 2          27.70                       5.00           76.67
# 3          52.10                       4.20           75.09
# 4          16.50                       3.84           83.44
# ..           ...                        ...             ...
# 108        24.60                       2.77           78.86
# 109        19.90                       2.80           77.91
# 110        45.90                       2.60           75.40
# 111        24.70                       2.00           63.89
# 112        30.70                       1.70           61.49
#
#     human_development_index
# 0                      0.80
# 1                      0.87
# 2                      0.84
# 3                      0.78
# 4                      0.94
# ..                      ...
# 108                    0.93
# 109                    0.82
# 110                    0.70
# 111                    0.58
# 112                    0.57
#
# [113 rows x 24 columns]

# %% [markdown]
# ## Global Stats vs Vaccine data

# %%
# Each country vaccine data for stats
vaccine_stats = pd.DataFrame()
df = pd.DataFrame()

for country in countries:
    df = covid_data_df.loc[covid_data_df["location"] == country]
    num_vacc = df["total_vaccinations"].argmax()
    df = df.iloc[num_vacc].to_frame().T
    vaccine_stats = pd.concat([vaccine_stats,df])

del df

# %%
vaccine_stats = vaccine_stats.dropna(subset=['total_vaccinations'])
vaccine_stats_df = vaccine_stats[["iso_code","continent","location","total_vaccinations","people_vaccinated","people_fully_vaccinated","total_vaccinations_per_hundred","people_vaccinated_per_hundred","people_fully_vaccinated_per_hundred"]]
vaccine_stats_df
# Out:
#        iso_code      continent     location total_vaccinations  \
# 408         AFG           Asia  Afghanistan          120000.00
# 836    OWID_AFR            NaN       Africa        13477122.00
# 1247        ALB         Europe      Albania          256810.00
# 1609        DZA         Africa      Algeria           75000.00
# 2066        AND         Europe      Andorra           17091.00
# ...         ...            ...          ...                ...
# 78000       UZB           Asia   Uzbekistan          148642.00
# 78940       VEN  South America    Venezuela           98000.00
# 79392       VNM           Asia      Vietnam           58037.00
# 79840  OWID_WRL            NaN        World       788189884.00
# 80984       ZWE         Africa     Zimbabwe          222733.00
#
#       people_vaccinated people_fully_vaccinated new_vaccinations  \
# 408           120000.00                     NaN              NaN
# 836          8962280.00              4502546.00         86405.00
# 1247                NaN                     NaN          6134.00
# 1609                NaN                     NaN              NaN
# 2066                NaN                     NaN              NaN
# ...                 ...                     ...              ...
# 78000         148642.00                     NaN              NaN
# 78940          98000.00                     NaN              NaN
# 79392          58037.00                     NaN          1678.00
# 79840      439334176.00            172417377.00      11757158.00
# 80984         193936.00                28797.00         16528.00
#
#       total_vaccinations_per_hundred people_vaccinated_per_hundred  \
# 408                             0.31                          0.31
# 836                             1.01                          0.67
# 1247                            8.92                           NaN
# 1609                            0.17                           NaN
# 2066                           22.12                           NaN
# ...                              ...                           ...
# 78000                           0.44                          0.44
# 78940                           0.34                          0.34
# 79392                           0.06                          0.06
# 79840                          10.11                          5.64
# 80984                           1.50                          1.30
#
#       people_fully_vaccinated_per_hundred
# 408                                   NaN
# 836                                  0.34
# 1247                                  NaN
# 1609                                  NaN
# 2066                                  NaN
# ...                                   ...
# 78000                                 NaN
# 78940                                 NaN
# 79392                                 NaN
# 79840                                2.21
# 80984                                0.19
#
# [180 rows x 10 columns]

# %%
more_vaccine_stats = vaccine_stats[["iso_code", "continent", "location", "total_vaccinations", "population", "population_density", "median_age", "aged_65_older", "aged_70_older", "gdp_per_capita", "extreme_poverty", "cardiovasc_death_rate", "diabetes_prevalence", "female_smokers", "male_smokers", "hospital_beds_per_thousand", "life_expectancy", "human_development_index"]]
more_vaccine_stats
# Out:
#        iso_code      continent     location total_vaccinations    population  \
# 408         AFG           Asia  Afghanistan          120000.00   38928341.00
# 836    OWID_AFR            NaN       Africa        13477122.00 1340598113.00
# 1247        ALB         Europe      Albania          256810.00    2877800.00
# 1609        DZA         Africa      Algeria           75000.00   43851043.00
# 2066        AND         Europe      Andorra           17091.00      77265.00
# ...         ...            ...          ...                ...           ...
# 78000       UZB           Asia   Uzbekistan          148642.00   33469199.00
# 78940       VEN  South America    Venezuela           98000.00   28435943.00
# 79392       VNM           Asia      Vietnam           58037.00   97338583.00
# 79840  OWID_WRL            NaN        World       788189884.00 7794798729.00
# 80984       ZWE         Africa     Zimbabwe          222733.00   14862927.00
#
#       population_density median_age aged_65_older aged_70_older  \
# 408                54.42      18.60          2.58          1.34
# 836                  NaN        NaN           NaN           NaN
# 1247              104.87      38.00         13.19          8.64
# 1609               17.35      29.10          6.21          3.86
# 2066              163.75        NaN           NaN           NaN
# ...                  ...        ...           ...           ...
# 78000              76.13      28.20          4.47          2.87
# 78940              36.25      29.00          6.61          3.92
# 79392             308.13      32.60          7.15          4.72
# 79840              58.05      30.90          8.70          5.36
# 80984              42.73      19.60          2.82          1.88
#
#       gdp_per_capita extreme_poverty cardiovasc_death_rate  \
# 408          1803.99             NaN                597.03
# 836              NaN             NaN                   NaN
# 1247        11803.43            1.10                304.19
# 1609        13913.84            0.50                278.36
# 2066             NaN             NaN                109.14
# ...              ...             ...                   ...
# 78000        6253.10             NaN                724.42
# 78940       16745.02             NaN                204.85
# 79392        6171.88            2.00                245.47
# 79840       15469.21           10.00                233.07
# 80984        1899.78           21.40                307.85
#
#       diabetes_prevalence female_smokers male_smokers  \
# 408                  9.59            NaN          NaN
# 836                   NaN            NaN          NaN
# 1247                10.08           7.10        51.20
# 1609                 6.73           0.70        30.40
# 2066                 7.97          29.00        37.80
# ...                   ...            ...          ...
# 78000                7.57           1.30        24.70
# 78940                6.47            NaN          NaN
# 79392                6.00           1.00        45.90
# 79840                8.51           6.43        34.63
# 80984                1.82           1.60        30.70
#
#       hospital_beds_per_thousand life_expectancy human_development_index
# 408                         0.50           64.83                    0.51
# 836                          NaN             NaN                     NaN
# 1247                        2.89           78.57                    0.80
# 1609                        1.90           76.88                    0.75
# 2066                         NaN           83.73                    0.87
# ...                          ...             ...                     ...
# 78000                       4.00           71.72                    0.72
# 78940                       0.80           72.06                    0.71
# 79392                       2.60           75.40                    0.70
# 79840                       2.71           72.58                    0.74
# 80984                       1.70           61.49                    0.57
#
# [180 rows x 18 columns]

# %%
ready_vaccine_stats = vaccine_stats_df.merge(more_vaccine_stats, how="inner", on=["iso_code","continent","location","total_vaccinations"])
ready_vaccine_stats
# Out:
#      iso_code      continent     location total_vaccinations  \
# 0         AFG           Asia  Afghanistan          120000.00
# 1    OWID_AFR            NaN       Africa        13477122.00
# 2         ALB         Europe      Albania          256810.00
# 3         DZA         Africa      Algeria           75000.00
# 4         AND         Europe      Andorra           17091.00
# ..        ...            ...          ...                ...
# 175       UZB           Asia   Uzbekistan          148642.00
# 176       VEN  South America    Venezuela           98000.00
# 177       VNM           Asia      Vietnam           58037.00
# 178  OWID_WRL            NaN        World       788189884.00
# 179       ZWE         Africa     Zimbabwe          222733.00
#
#     people_vaccinated people_fully_vaccinated new_vaccinations  \
# 0           120000.00                     NaN              NaN
# 1          8962280.00              4502546.00         86405.00
# 2                 NaN                     NaN          6134.00
# 3                 NaN                     NaN              NaN
# 4                 NaN                     NaN              NaN
# ..                ...                     ...              ...
# 175         148642.00                     NaN              NaN
# 176          98000.00                     NaN              NaN
# 177          58037.00                     NaN          1678.00
# 178      439334176.00            172417377.00      11757158.00
# 179         193936.00                28797.00         16528.00
#
#     total_vaccinations_per_hundred people_vaccinated_per_hundred  \
# 0                             0.31                          0.31
# 1                             1.01                          0.67
# 2                             8.92                           NaN
# 3                             0.17                           NaN
# 4                            22.12                           NaN
# ..                             ...                           ...
# 175                           0.44                          0.44
# 176                           0.34                          0.34
# 177                           0.06                          0.06
# 178                          10.11                          5.64
# 179                           1.50                          1.30
#
#     people_fully_vaccinated_per_hundred  ... aged_70_older gdp_per_capita  \
# 0                                   NaN  ...          1.34        1803.99
# 1                                  0.34  ...           NaN            NaN
# 2                                   NaN  ...          8.64       11803.43
# 3                                   NaN  ...          3.86       13913.84
# 4                                   NaN  ...           NaN            NaN
# ..                                  ...  ...           ...            ...
# 175                                 NaN  ...          2.87        6253.10
# 176                                 NaN  ...          3.92       16745.02
# 177                                 NaN  ...          4.72        6171.88
# 178                                2.21  ...          5.36       15469.21
# 179                                0.19  ...          1.88        1899.78
#
#     extreme_poverty cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 0               NaN                597.03                9.59            NaN
# 1               NaN                   NaN                 NaN            NaN
# 2              1.10                304.19               10.08           7.10
# 3              0.50                278.36                6.73           0.70
# 4               NaN                109.14                7.97          29.00
# ..              ...                   ...                 ...            ...
# 175             NaN                724.42                7.57           1.30
# 176             NaN                204.85                6.47            NaN
# 177            2.00                245.47                6.00           1.00
# 178           10.00                233.07                8.51           6.43
# 179           21.40                307.85                1.82           1.60
#
#     male_smokers hospital_beds_per_thousand life_expectancy  \
# 0            NaN                       0.50           64.83
# 1            NaN                        NaN             NaN
# 2          51.20                       2.89           78.57
# 3          30.40                       1.90           76.88
# 4          37.80                        NaN           83.73
# ..           ...                        ...             ...
# 175        24.70                       4.00           71.72
# 176          NaN                       0.80           72.06
# 177        45.90                       2.60           75.40
# 178        34.63                       2.71           72.58
# 179        30.70                       1.70           61.49
#
#     human_development_index
# 0                      0.51
# 1                       NaN
# 2                      0.80
# 3                      0.75
# 4                      0.87
# ..                      ...
# 175                    0.72
# 176                    0.71
# 177                    0.70
# 178                    0.74
# 179                    0.57
#
# [180 rows x 24 columns]

# %% [markdown]
# ## US COVID-19 Data

# %%
# Get data from US only
covid_data_df_us = covid_data_df.loc[covid_data_df["location"] == "United States"]
covid_data_df_us
# Out:
#       iso_code      continent       location        date  total_cases  \
# 76767      USA  North America  United States  2020-01-22        1.000
# 76768      USA  North America  United States  2020-01-23        1.000
# 76769      USA  North America  United States  2020-01-24        2.000
# 76770      USA  North America  United States  2020-01-25        2.000
# 76771      USA  North America  United States  2020-01-26        5.000
# ...        ...            ...            ...         ...          ...
# 77208      USA  North America  United States  2021-04-07 30922386.000
# 77209      USA  North America  United States  2021-04-08 31002264.000
# 77210      USA  North America  United States  2021-04-09 31084962.000
# 77211      USA  North America  United States  2021-04-10 31151495.000
# 77212      USA  North America  United States  2021-04-11 31197873.000
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 76767        nan                 nan           nan         nan
# 76768      0.000                 nan           nan         nan
# 76769      1.000                 nan           nan         nan
# 76770      0.000                 nan           nan         nan
# 76771      3.000                 nan           nan         nan
# ...          ...                 ...           ...         ...
# 77208  75038.000           65936.000    559202.000    2570.000
# 77209  79878.000           66056.571    560202.000    1000.000
# 77210  82698.000           67896.000    561074.000     872.000
# 77211  66533.000           68404.429    561783.000     709.000
# 77212  46378.000           70039.571    562066.000     283.000
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 76767                  nan  ...       54225.446            1.200
# 76768                  nan  ...       54225.446            1.200
# 76769                  nan  ...       54225.446            1.200
# 76770                  nan  ...       54225.446            1.200
# 76771                  nan  ...       54225.446            1.200
# ...                    ...  ...             ...              ...
# 77208              989.286  ...       54225.446            1.200
# 77209              979.571  ...       54225.446            1.200
# 77210              970.000  ...       54225.446            1.200
# 77211              969.429  ...       54225.446            1.200
# 77212              969.286  ...       54225.446            1.200
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 76767                151.089               10.790          19.100
# 76768                151.089               10.790          19.100
# 76769                151.089               10.790          19.100
# 76770                151.089               10.790          19.100
# 76771                151.089               10.790          19.100
# ...                      ...                  ...             ...
# 77208                151.089               10.790          19.100
# 77209                151.089               10.790          19.100
# 77210                151.089               10.790          19.100
# 77211                151.089               10.790          19.100
# 77212                151.089               10.790          19.100
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 76767        24.600                     nan                       2.770
# 76768        24.600                     nan                       2.770
# 76769        24.600                     nan                       2.770
# 76770        24.600                     nan                       2.770
# 76771        24.600                     nan                       2.770
# ...             ...                     ...                         ...
# 77208        24.600                     nan                       2.770
# 77209        24.600                     nan                       2.770
# 77210        24.600                     nan                       2.770
# 77211        24.600                     nan                       2.770
# 77212        24.600                     nan                       2.770
#
#        life_expectancy  human_development_index
# 76767           78.860                    0.926
# 76768           78.860                    0.926
# 76769           78.860                    0.926
# 76770           78.860                    0.926
# 76771           78.860                    0.926
# ...                ...                      ...
# 77208           78.860                    0.926
# 77209           78.860                    0.926
# 77210           78.860                    0.926
# 77211           78.860                    0.926
# 77212           78.860                    0.926
#
# [446 rows x 59 columns]

# %%
# Date, total cases, new cases, and deaths data
covid_numbers_us_df = covid_data_df_us[["location", "date", "total_cases", "new_cases", "total_deaths", "new_deaths", "total_cases_per_million", "new_cases_per_million", "total_deaths_per_million", "new_deaths_per_million"]]
covid_numbers_us_df
# Out:
#             location        date  total_cases  new_cases  total_deaths  \
# 76767  United States  2020-01-22        1.000        nan           nan
# 76768  United States  2020-01-23        1.000      0.000           nan
# 76769  United States  2020-01-24        2.000      1.000           nan
# 76770  United States  2020-01-25        2.000      0.000           nan
# 76771  United States  2020-01-26        5.000      3.000           nan
# ...              ...         ...          ...        ...           ...
# 77208  United States  2021-04-07 30922386.000  75038.000    559202.000
# 77209  United States  2021-04-08 31002264.000  79878.000    560202.000
# 77210  United States  2021-04-09 31084962.000  82698.000    561074.000
# 77211  United States  2021-04-10 31151495.000  66533.000    561783.000
# 77212  United States  2021-04-11 31197873.000  46378.000    562066.000
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# 76767         nan                    0.003                    nan
# 76768         nan                    0.003                  0.000
# 76769         nan                    0.006                  0.003
# 76770         nan                    0.006                  0.000
# 76771         nan                    0.015                  0.009
# ...           ...                      ...                    ...
# 77208    2570.000                93420.359                226.699
# 77209    1000.000                93661.680                241.321
# 77210     872.000                93911.521                249.841
# 77211     709.000                94112.525                201.004
# 77212     283.000                94252.639                140.114
#
#        total_deaths_per_million  new_deaths_per_million
# 76767                       nan                     nan
# 76768                       nan                     nan
# 76769                       nan                     nan
# 76770                       nan                     nan
# 76771                       nan                     nan
# ...                         ...                     ...
# 77208                  1689.419                   7.764
# 77209                  1692.440                   3.021
# 77210                  1695.074                   2.634
# 77211                  1697.216                   2.142
# 77212                  1698.071                   0.855
#
# [446 rows x 10 columns]

# %%
# Test data
covid_testdata_df_us = covid_data_df_us[["location", "date", "new_tests", "total_tests", "total_tests_per_thousand", "new_tests_per_thousand", "positive_rate", "tests_per_case"]]
# Keep only the rows with at least 2 non-NA values.
covid_testdata_df_us = covid_testdata_df_us.dropna(thresh=3)
covid_testdata_df_us
# Out:
#             location        date   new_tests   total_tests  \
# 76806  United States  2020-03-01     372.000       372.000
# 76807  United States  2020-03-02     550.000       922.000
# 76808  United States  2020-03-03     933.000      1855.000
# 76809  United States  2020-03-04     924.000      2779.000
# 76810  United States  2020-03-05    1205.000      3984.000
# ...              ...         ...         ...           ...
# 77203  United States  2021-04-02 1210503.000 382758324.000
# 77204  United States  2021-04-03  841444.000 383599768.000
# 77205  United States  2021-04-04  450322.000 384050090.000
# 77206  United States  2021-04-05  530002.000 384580092.000
# 77207  United States  2021-04-06  484155.000 385064247.000
#
#        total_tests_per_thousand  new_tests_per_thousand  positive_rate  \
# 76806                     0.001                   0.001            nan
# 76807                     0.003                   0.002            nan
# 76808                     0.006                   0.003            nan
# 76809                     0.008                   0.003            nan
# 76810                     0.012                   0.004            nan
# ...                         ...                     ...            ...
# 77203                  1156.360                   3.657          0.055
# 77204                  1158.902                   2.542          0.057
# 77205                  1160.263                   1.360          0.057
# 77206                  1161.864                   1.601          0.061
# 77207                  1163.327                   1.463          0.070
#
#        tests_per_case
# 76806             nan
# 76807             nan
# 76808             nan
# 76809             nan
# 76810             nan
# ...               ...
# 77203          18.200
# 77204          17.500
# 77205          17.500
# 77206          16.400
# 77207          14.300
#
# [402 rows x 8 columns]

# %%
# Can date be a primary key? Since all vaslues have to be unique, if the lenght of the unique array matches the length of the column date then all values are unique

if len(covid_testdata_df_us["date"].unique()) == len(covid_testdata_df_us["date"]):
    print("Date can be a primary key")
else:
    print("Date can't be a primary key")
# Out:
# Date can be a primary key

# %%
covid_data_state = "./resources/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv"

covid_data_state_df = pd.read_csv(covid_data_state, low_memory=False)

covid_data_state_df
# Out:
# D:\Usuarios\Javi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 0           2020-02       NaN              NaN        NaN               NaN
# 1           2020-02       NaN              NaN        NaN               NaN
# 2           2020-02       NaN              NaN        NaN               NaN
# 3           2020-08       NaN              NaN        NaN               NaN
# 4           2020-08       NaN              NaN        NaN               NaN
# ...             ...       ...              ...        ...               ...
# 22507134    2020-12        AZ              4.0       YUMA            4027.0
# 22507135    2020-12        AZ              4.0       YUMA            4027.0
# 22507136    2020-12        AZ              4.0       YUMA            4027.0
# 22507137    2020-12        AZ              4.0       YUMA            4027.0
# 22507138    2020-12        AZ              4.0       YUMA            4027.0
#
#           age_group   sex   race            ethnicity  \
# 0               NaN   NaN    NaN                  NaN
# 1               NaN   NaN    NaN                  NaN
# 2               NaN   NaN    NaN                  NaN
# 3               NaN   NaN    NaN                  NaN
# 4               NaN   NaN    NaN                  NaN
# ...             ...   ...    ...                  ...
# 22507134  65+ years  Male  White  Non-Hispanic/Latino
# 22507135  65+ years  Male  White  Non-Hispanic/Latino
# 22507136  65+ years  Male  White  Non-Hispanic/Latino
# 22507137  65+ years  Male  White  Non-Hispanic/Latino
# 22507138  65+ years  Male  White  Non-Hispanic/Latino
#
#           case_positive_specimen_interval  case_onset_interval  \
# 0                                     NaN                  0.0
# 1                                     3.0                  0.0
# 2                                     NaN                  0.0
# 3                                     0.0                  NaN
# 4                                     0.0                  NaN
# ...                                   ...                  ...
# 22507134                              NaN                  NaN
# 22507135                              NaN                  NaN
# 22507136                              NaN                  NaN
# 22507137                              NaN                  NaN
# 22507138                              NaN                  NaN
#
#                        process exposure_yn             current_status  \
# 0                      Missing     Missing  Laboratory-confirmed case
# 1          Clinical evaluation         Yes  Laboratory-confirmed case
# 2          Clinical evaluation     Missing  Laboratory-confirmed case
# 3         Routine surveillance     Missing  Laboratory-confirmed case
# 4         Routine surveillance     Missing  Laboratory-confirmed case
# ...                        ...         ...                        ...
# 22507134               Missing     Missing  Laboratory-confirmed case
# 22507135               Missing     Missing  Laboratory-confirmed case
# 22507136               Missing     Missing  Laboratory-confirmed case
# 22507137               Missing     Missing  Laboratory-confirmed case
# 22507138               Missing     Missing  Laboratory-confirmed case
#
#          symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0           Symptomatic      Yes  Missing      NaN                      NaN
# 1           Symptomatic      Yes      Yes      NaN                      Yes
# 2           Symptomatic      Yes       No      NaN                      Yes
# 3          Asymptomatic       No       No  Missing                      Yes
# 4               Missing  Missing  Missing  Missing                      Yes
# ...                 ...      ...      ...      ...                      ...
# 22507134        Missing      Yes  Missing      Yes                      NaN
# 22507135        Missing  Missing  Missing      Yes                      NaN
# 22507136        Missing      Yes  Missing      Yes                      NaN
# 22507137        Missing      Yes  Missing      Yes                      NaN
# 22507138        Missing      Yes  Missing      Yes                      NaN
#
# [22507139 rows x 19 columns]

# %%
# California data
covid_data_CA = covid_data_state_df.loc[covid_data_state_df["res_state"] == "CA"]
covid_data_CA
# Out:
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 205         2020-12        CA              6.0        NaN               NaN
# 206         2020-12        CA              6.0        NaN               NaN
# 207         2020-12        CA              6.0        NaN               NaN
# 7413        2020-03        CA              6.0      BUTTE            6007.0
# 7414        2020-03        CA              6.0      BUTTE            6007.0
# ...             ...       ...              ...        ...               ...
# 22506961    2020-12        CA              6.0       YOLO            6113.0
# 22506962    2020-12        CA              6.0       YOLO            6113.0
# 22506963    2020-12        CA              6.0       YOLO            6113.0
# 22506964    2020-12        CA              6.0       YOLO            6113.0
# 22506965    2020-12        CA              6.0       YOLO            6113.0
#
#           age_group   sex   race            ethnicity  \
# 205         Missing   NaN    NaN                  NaN
# 206         Missing   NaN    NaN                  NaN
# 207             NaN   NaN    NaN                  NaN
# 7413            NaN   NaN    NaN                  NaN
# 7414            NaN   NaN    NaN                  NaN
# ...             ...   ...    ...                  ...
# 22506961  65+ years  Male  White  Non-Hispanic/Latino
# 22506962  65+ years  Male  White  Non-Hispanic/Latino
# 22506963  65+ years  Male  White  Non-Hispanic/Latino
# 22506964  65+ years  Male  White  Non-Hispanic/Latino
# 22506965  65+ years  Male  White  Non-Hispanic/Latino
#
#           case_positive_specimen_interval  case_onset_interval  process  \
# 205                                   NaN                  0.0  Missing
# 206                                   NaN                  NaN  Missing
# 207                                   NaN                  0.0  Missing
# 7413                                  NaN                  0.0  Missing
# 7414                                  NaN                  0.0  Missing
# ...                                   ...                  ...      ...
# 22506961                              NaN                  NaN  Missing
# 22506962                              NaN                  0.0  Missing
# 22506963                              NaN                  NaN  Missing
# 22506964                              NaN                  NaN  Missing
# 22506965                              NaN                  NaN  Missing
#
#          exposure_yn             current_status symptom_status hosp_yn  \
# 205          Missing  Laboratory-confirmed case    Symptomatic     Yes
# 206          Missing  Laboratory-confirmed case        Unknown      No
# 207          Missing  Laboratory-confirmed case    Symptomatic     Yes
# 7413         Missing  Laboratory-confirmed case    Symptomatic      No
# 7414         Missing  Laboratory-confirmed case    Symptomatic     Yes
# ...              ...                        ...            ...     ...
# 22506961     Missing  Laboratory-confirmed case        Unknown      No
# 22506962     Missing  Laboratory-confirmed case    Symptomatic     Yes
# 22506963     Missing  Laboratory-confirmed case        Unknown     Yes
# 22506964     Missing  Laboratory-confirmed case        Unknown     Yes
# 22506965     Missing  Laboratory-confirmed case        Unknown     Yes
#
#            icu_yn death_yn underlying_conditions_yn
# 205       Missing      NaN                      NaN
# 206       Missing      NaN                      NaN
# 207       Unknown      NaN                      NaN
# 7413      Missing       No                      NaN
# 7414           No       No                      NaN
# ...           ...      ...                      ...
# 22506961  Missing      NaN                      NaN
# 22506962      Yes      NaN                      NaN
# 22506963      Yes      NaN                      NaN
# 22506964  Missing      NaN                      NaN
# 22506965  Missing      NaN                      NaN
#
# [3547519 rows x 19 columns]

# %% [markdown]
# ## COVID-19 US Vactination Data

# %%
us_vaccination = "./resources/us_state_vaccinations.csv"

us_vaccination_df = pd.read_csv(us_vaccination)

us_vaccination_df
# Out:
#             date location  total_vaccinations  total_distributed  \
# 0     2021-01-12  Alabama             78134.0           377025.0
# 1     2021-01-13  Alabama             84040.0           378975.0
# 2     2021-01-14  Alabama             92300.0           435350.0
# 3     2021-01-15  Alabama            100567.0           444650.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 5933  2021-04-08  Wyoming            288814.0           436025.0
# 5934  2021-04-09  Wyoming            289028.0           447855.0
# 5935  2021-04-10  Wyoming            289340.0           450525.0
# 5936  2021-04-11  Wyoming            310702.0           450525.0
# 5937  2021-04-12  Wyoming            310765.0           450525.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# 1               74792.0                                 0.19
# 2               80480.0                                  NaN
# 3               86956.0                                 0.28
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 5933           169230.0                                20.75
# 5934           169409.0                                20.78
# 5935           169683.0                                20.83
# 5936           180223.0                                22.80
# 5937           180275.0                                22.81
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                               1.59                   7270.0
# 1                               1.71                   9245.0
# 2                               1.88                      NaN
# 3                               2.05                  13488.0
# 4                                NaN                      NaN
# ...                              ...                      ...
# 5933                           49.90                 120094.0
# 5934                           49.94                 120246.0
# 5935                           49.99                 120534.0
# 5936                           53.68                 131933.0
# 5937                           53.70                 131994.0
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                              1.45                     7.69
# 1                              1.53                     7.73
# 2                              1.64                     8.88
# 3                              1.77                     9.07
# 4                               NaN                      NaN
# ...                             ...                      ...
# 5933                          29.24                    75.34
# 5934                          29.27                    77.38
# 5935                          29.32                    77.84
# 5936                          31.14                    77.84
# 5937                          31.15                    77.84
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                 NaN
# 1                     5906.0              5906.0
# 2                     8260.0              7083.0
# 3                     8267.0              7478.0
# 4                     7557.0              7498.0
# ...                      ...                 ...
# 5933                   228.0              2655.0
# 5934                   214.0              2633.0
# 5935                   312.0              2640.0
# 5936                 21362.0              3431.0
# 5937                    63.0              3400.0
#
#       daily_vaccinations_per_million  share_doses_used
# 0                                NaN             0.207
# 1                             1205.0             0.222
# 2                             1445.0             0.212
# 3                             1525.0             0.226
# 4                             1529.0               NaN
# ...                              ...               ...
# 5933                          4587.0             0.662
# 5934                          4549.0             0.645
# 5935                          4561.0             0.642
# 5936                          5928.0             0.690
# 5937                          5875.0             0.690
#
# [5938 rows x 14 columns]

# %%
ca_us_vaccination_df = us_vaccination_df.loc[us_vaccination_df["location"] == "California"]
ca_us_vaccination_df
# Out:
#            date    location  total_vaccinations  total_distributed  \
# 546  2021-01-12  California            816301.0          3286050.0
# 547  2021-01-13  California            891489.0          3435650.0
# 548  2021-01-14  California            975293.0          3540175.0
# 549  2021-01-15  California           1072959.0          3548575.0
# 550  2021-01-16  California                 NaN                NaN
# ..          ...         ...                 ...                ...
# 632  2021-04-08  California          21243518.0         27861050.0
# 633  2021-04-09  California          21725654.0         28532520.0
# 634  2021-04-10  California          22281619.0         29034050.0
# 635  2021-04-11  California          22754163.0         29034050.0
# 636  2021-04-12  California          23031055.0         29034050.0
#
#      people_vaccinated  people_fully_vaccinated_per_hundred  \
# 546           703540.0                                 0.25
# 547           744545.0                                 0.34
# 548           801998.0                                  NaN
# 549           865387.0                                 0.52
# 550                NaN                                  NaN
# ..                 ...                                  ...
# 632         14123008.0                                19.23
# 633         14445185.0                                19.80
# 634         14803675.0                                20.53
# 635         15123816.0                                21.09
# 636         15320888.0                                21.41
#
#      total_vaccinations_per_hundred  people_fully_vaccinated  \
# 546                            2.07                 100089.0
# 547                            2.26                 133689.0
# 548                            2.47                      NaN
# 549                            2.72                 204374.0
# 550                             NaN                      NaN
# ..                              ...                      ...
# 632                           53.76                7599559.0
# 633                           54.98                7822226.0
# 634                           56.39                8110488.0
# 635                           57.59                8332396.0
# 636                           58.29                8459357.0
#
#      people_vaccinated_per_hundred  distributed_per_hundred  \
# 546                           1.78                     8.32
# 547                           1.88                     8.70
# 548                           2.03                     8.96
# 549                           2.19                     8.98
# 550                            NaN                      NaN
# ..                             ...                      ...
# 632                          35.74                    70.51
# 633                          36.56                    72.21
# 634                          37.47                    73.48
# 635                          38.28                    73.48
# 636                          38.78                    73.48
#
#      daily_vaccinations_raw  daily_vaccinations  \
# 546                     NaN                 NaN
# 547                75188.00             75188.0
# 548                83804.00             79496.0
# 549                97666.00             85553.0
# 550                96867.75             88381.0
# ..                      ...                 ...
# 632               377626.00            377051.0
# 633               482136.00            391393.0
# 634               555965.00            404572.0
# 635               472544.00            398820.0
# 636               276892.00            388844.0
#
#      daily_vaccinations_per_million  share_doses_used
# 546                             NaN             0.248
# 547                          1903.0             0.259
# 548                          2012.0             0.275
# 549                          2165.0             0.302
# 550                          2237.0               NaN
# ..                              ...               ...
# 632                          9543.0             0.762
# 633                          9906.0             0.761
# 634                         10239.0             0.767
# 635                         10094.0             0.784
# 636                          9841.0             0.793
#
# [91 rows x 14 columns]

# %%
vaccination_by_man = "./resources/vaccinations-by-manufacturer.csv"

vaccination_by_man_df = pd.read_csv(vaccination_by_man)

vaccination_by_man_df
# Out:
#            location        date          vaccine  total_vaccinations
# 0             Chile  2020-12-24  Pfizer/BioNTech                 420
# 1             Chile  2020-12-25  Pfizer/BioNTech                5198
# 2             Chile  2020-12-26  Pfizer/BioNTech                8338
# 3             Chile  2020-12-27  Pfizer/BioNTech                8649
# 4             Chile  2020-12-28  Pfizer/BioNTech                8649
# ...             ...         ...              ...                 ...
# 2261  United States  2021-04-10          Moderna            82622178
# 2262  United States  2021-04-10  Pfizer/BioNTech            94715143
# 2263  United States  2021-04-11  Johnson&Johnson             6453740
# 2264  United States  2021-04-11          Moderna            83847244
# 2265  United States  2021-04-11  Pfizer/BioNTech            96586783
#
# [2266 rows x 4 columns]

# %%
vaccination_by_man_us_df =  vaccination_by_man_df.loc[vaccination_by_man_df["location"] == "United States"]
vaccination_by_man_us_df
# Out:
#            location        date          vaccine  total_vaccinations
# 2061  United States  2021-01-12          Moderna             3835859
# 2062  United States  2021-01-12  Pfizer/BioNTech             5488697
# 2063  United States  2021-01-13          Moderna             4249795
# 2064  United States  2021-01-13  Pfizer/BioNTech             6025872
# 2065  United States  2021-01-15          Moderna             5122662
# ...             ...         ...              ...                 ...
# 2261  United States  2021-04-10          Moderna            82622178
# 2262  United States  2021-04-10  Pfizer/BioNTech            94715143
# 2263  United States  2021-04-11  Johnson&Johnson             6453740
# 2264  United States  2021-04-11          Moderna            83847244
# 2265  United States  2021-04-11  Pfizer/BioNTech            96586783
#
# [205 rows x 4 columns]
